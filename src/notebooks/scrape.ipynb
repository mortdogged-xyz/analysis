# %%
from IPython.display import clear_output
import time

# %%
while True:
    clear_output()
    # !cd ../.. && make scrape export
    time.sleep(120)
# Out:
# make[1]: Entering directory '/home/gnzh/work/mortdogged/analysis'
# poetry run python src/main.py scrape
# 2022-09-04 16:18:19 nas root[3611404] INFO Namespace(config='config.yaml', func=<function scrape at 0x7f59b035c310>)
# 2022-09-04 16:18:19 nas root[3611404] INFO riot=RiotConfig(token='RGAPI-91ee45dc-836a-4631-8ea5-950439203927') scrape=ScrapeConfig(region='NA', cache_dir='/storage/samba/work/gnzh/mortdogged/analysis/cache', data_dir='/storage/samba/work/gnzh/mortdogged/analysis/data', sleep=1, leagues=['challenger'])
# 2022-09-04 16:18:19 nas root[3611404] INFO Removing stale /storage/samba/work/gnzh/mortdogged/analysis/cache/get-e2df10eaebc8ae8d9bed7951d17e48b4.json
# 2022-09-04 16:18:19 nas urllib3.connectionpool[3611404] DEBUG Starting new HTTPS connection (1): na1.api.riotgames.com:443
# 2022-09-04 16:18:20 nas urllib3.connectionpool[3611404] DEBUG https://na1.api.riotgames.com:443 "GET /tft/league/v1/challenger HTTP/1.1" 200 None
# ...
